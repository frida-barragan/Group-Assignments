# %%
import pandas as pd 
import geopandas as gpd 
import contextily as ctx 
import matplotlib.pyplot as plt

# %%
hcs = gpd.read_file("datasets/Health_Clinics.geojson")

# %%
hcs.head()
# Out:
#    OBJECTID source ext_id                      cat1            cat2  cat3  \
# 0        12    211   None  Health and Mental Health  Health Clinics  None
# 1        15    211   None  Health and Mental Health  Health Clinics  None
# 2        97    211   None  Health and Mental Health  Health Clinics  None
# 3       102    211   None  Health and Mental Health  Health Clinics  None
# 4       104    211   None  Health and Mental Health  Health Clinics  None
#
#                                             org_name  \
# 0                              http://www.vnahhs.com
# 1                                 www.pppasadena.org
# 2
# 3  california.providence.org/torrance/Pages/defau...
# 4  california.providence.org/torrance/Pages/defau...
#
#                                                 Name               addrln1  \
# 0                                           VNA Care  3452 E Foothill Blvd
# 1  Planned Parenthood Pasadena And San Gabriel Va...     1045 N. Lake Ave.
# 2  The Children's Clinic at International Element...       700 Locust Ave.
# 3  Providence Little Company Of Mary Medical Cent...     1403 Lomita Blvd.
# 4  Providence Little Company Of Mary Medical Cent...     4320 Maricopa St.
#
#   addrln2  ...                                  link use_type   latitude  \
# 0    None  ...  http://egis3.lacounty.gov/lms/?p=562  publish  34.149155
# 1    None  ...  http://egis3.lacounty.gov/lms/?p=564  publish  34.163960
# 2    None  ...  http://egis3.lacounty.gov/lms/?p=582  publish  33.776370
# 3    None  ...  http://egis3.lacounty.gov/lms/?p=587  publish  33.797949
# 4    None  ...  http://egis3.lacounty.gov/lms/?p=588  publish  33.839399
#
#     longitude               date_updated email dis_status       POINT_X  \
# 0 -118.078390  2017-10-31T17:20:52+00:00  None       None  6.537953e+06
# 1 -118.132931  2013-06-01T11:50:56+00:00  None       None  6.521458e+06
# 2 -118.190694  2013-05-29T13:50:38+00:00  None       None  6.503716e+06
# 3 -118.301215  2013-06-01T11:50:56+00:00  None       None  6.470151e+06
# 4 -118.359716  2013-06-01T11:50:56+00:00  None       None  6.452431e+06
#
#         POINT_Y                     geometry
# 0  1.876670e+06  POINT (-118.07839 34.14915)
# 1  1.882075e+06  POINT (-118.13293 34.16396)
# 2  1.741051e+06  POINT (-118.19069 33.77637)
# 3  1.748986e+06  POINT (-118.30122 33.79795)
# 4  1.764129e+06  POINT (-118.35972 33.83940)
#
# [5 rows x 30 columns]

# %%
hcs.plot(figsize=(10,10))

# %%
hcs.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      281 non-null    int64
#  1   source        274 non-null    object
#  2   ext_id        24 non-null     object
#  3   cat1          281 non-null    object
#  4   cat2          281 non-null    object
#  5   cat3          0 non-null      object
#  6   org_name      159 non-null    object
#  7   Name          281 non-null    object
#  8   addrln1       262 non-null    object
#  9   addrln2       41 non-null     object
#  10  city          262 non-null    object
#  11  state         262 non-null    object
#  12  hours         191 non-null    object
#  13  phones        260 non-null    object
#  14  url           233 non-null    object
#  15  info1         0 non-null      object
#  16  info2         0 non-null      object
#  17  post_id       281 non-null    int64
#  18  description   281 non-null    object
#  19  zip           262 non-null    object
#  20  link          281 non-null    object
#  21  use_type      281 non-null    object
#  22  latitude      281 non-null    float64
#  23  longitude     281 non-null    float64
#  24  date_updated  281 non-null    object
#  25  email         2 non-null      object
#  26  dis_status    1 non-null      object
#  27  POINT_X       281 non-null    float64
#  28  POINT_Y       281 non-null    float64
#  29  geometry      281 non-null    geometry
# dtypes: float64(4), geometry(1), int64(2), object(23)
# memory usage: 66.0+ KB

# %%
list(hcs)
# Out:
# ['OBJECTID',
#  'source',
#  'ext_id',
#  'cat1',
#  'cat2',
#  'cat3',
#  'org_name',
#  'Name',
#  'addrln1',
#  'addrln2',
#  'city',
#  'state',
#  'hours',
#  'phones',
#  'url',
#  'info1',
#  'info2',
#  'post_id',
#  'description',
#  'zip',
#  'link',
#  'use_type',
#  'latitude',
#  'longitude',
#  'date_updated',
#  'email',
#  'dis_status',
#  'POINT_X',
#  'POINT_Y',
#  'geometry']

# %%
# ctk means columns to keep 
ctk = [ 
    "cat1",
    "Name",
    "addrln1",
    "latitude",
    "longitude",
    "POINT_X",
    "POINT_Y",
    "geometry"
    
]

# %%
hcs = hcs[ctk]

# %%
hcs.head()
# Out:
#                        cat1  \
# 0  Health and Mental Health
# 1  Health and Mental Health
# 2  Health and Mental Health
# 3  Health and Mental Health
# 4  Health and Mental Health
#
#                                                 Name               addrln1  \
# 0                                           VNA Care  3452 E Foothill Blvd
# 1  Planned Parenthood Pasadena And San Gabriel Va...     1045 N. Lake Ave.
# 2  The Children's Clinic at International Element...       700 Locust Ave.
# 3  Providence Little Company Of Mary Medical Cent...     1403 Lomita Blvd.
# 4  Providence Little Company Of Mary Medical Cent...     4320 Maricopa St.
#
#     latitude   longitude       POINT_X       POINT_Y  \
# 0  34.149155 -118.078390  6.537953e+06  1.876670e+06
# 1  34.163960 -118.132931  6.521458e+06  1.882075e+06
# 2  33.776370 -118.190694  6.503716e+06  1.741051e+06
# 3  33.797949 -118.301215  6.470151e+06  1.748986e+06
# 4  33.839399 -118.359716  6.452431e+06  1.764129e+06
#
#                       geometry
# 0  POINT (-118.07839 34.14915)
# 1  POINT (-118.13293 34.16396)
# 2  POINT (-118.19069 33.77637)
# 3  POINT (-118.30122 33.79795)
# 4  POINT (-118.35972 33.83940)

# %%
hcs_web_mercator = hcs.to_crs(epsg = 3857)

# %%
fig, ax = plt.subplots(figsize = (15,15))
hcs_web_mercator.plot(ax=ax, alpha = 0.8)

ax.axis("off")
ax.set_title("title")
ctx.add_basemap(ax)
