# %% [markdown]
# <div class="alert-danger"><center> <h1>Los Angeles County Disparities in Healthcare Accessibility
#  </div>

# %% [markdown]
# Author: Frida Barragan
#
# Collaborator: Keven Michel (worked on a different notebook)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Los-Angeles-County-Disparities-in-Healthcare-Accessibility
# -" data-toc-modified-id="Los-Angeles-County-Disparities-in-Healthcare-Accessibility
# --1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Los Angeles County Disparities in Healthcare Accessibility
#  </a></span></li><li><span><a href="#-Introduction-" data-toc-modified-id="-Introduction--2"><span class="toc-item-num">2&nbsp;&nbsp;</span> Introduction </a></span><ul class="toc-item"><li><span><a href="#-Research-Question-&amp;-Goals-" data-toc-modified-id="-Research-Question-&amp;-Goals--2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span> Research Question &amp; Goals </a></span></li><li><span><a href="#-Project-Visualizations-" data-toc-modified-id="-Project-Visualizations--2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span> Project Visualizations </a></span></li></ul></li><li><span><a href="#-Choropleth-Map-of-Median-Household-Income-by-Zip-Code-in-LA-county" data-toc-modified-id="-Choropleth-Map-of-Median-Household-Income-by-Zip-Code-in-LA-county-3"><span class="toc-item-num">3&nbsp;&nbsp;</span> Choropleth Map of Median Household Income by Zip Code in LA county</a></span><ul class="toc-item"><li><span><a href="#Coding" data-toc-modified-id="Coding-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Coding</a></span><ul class="toc-item"><li><span><a href="#-Import-the-appropriate-libraries-and-extensions-to-read,-set-up-and-graph-the-data-appropriately." data-toc-modified-id="-Import-the-appropriate-libraries-and-extensions-to-read,-set-up-and-graph-the-data-appropriately.-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span> Import the appropriate libraries and extensions to read, set up and graph the data appropriately.</a></span></li><li><span><a href="#-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.-" data-toc-modified-id="-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.--3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span> Read the file where the data is stored and assign it to a variable. </a></span></li><li><span><a href="#-Visualize-all-the-rows-and-the-columns-in-the-data-set-without-any-limits/constraints.-" data-toc-modified-id="-Visualize-all-the-rows-and-the-columns-in-the-data-set-without-any-limits/constraints.--3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span> Visualize all the rows and the columns in the data set without any limits/constraints. </a></span></li><li><span><a href="#-Delete-the-row-in-the-data-that-contains-the-LA-County-information-to-prevent-errors-in-the-output-of-data-exploration.-" data-toc-modified-id="-Delete-the-row-in-the-data-that-contains-the-LA-County-information-to-prevent-errors-in-the-output-of-data-exploration.--3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span> Delete the row in the data that contains the LA County information to prevent errors in the output of data exploration. </a></span></li><li><span><a href="#-Visualize-the-first-five-rows-of-the-data-to-make-sure-there-are-no-mistakes-and-the-data-set-looks-clean.-" data-toc-modified-id="-Visualize-the-first-five-rows-of-the-data-to-make-sure-there-are-no-mistakes-and-the-data-set-looks-clean.--3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span> Visualize the first five rows of the data to make sure there are no mistakes and the data set looks clean. </a></span></li><li><span><a href="#-Select-the-appropriate-columns-needed-to-make-the-data-visualizations-and-assign-them-to-a-variable.-" data-toc-modified-id="-Select-the-appropriate-columns-needed-to-make-the-data-visualizations-and-assign-them-to-a-variable.--3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span> Select the appropriate columns needed to make the data visualizations and assign them to a variable. </a></span></li><li><span><a href="#-Visualize-the-first-five-rows-of-the-data.-" data-toc-modified-id="-Visualize-the-first-five-rows-of-the-data.--3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span> Visualize the first five rows of the data. </a></span></li><li><span><a href="#-Assign-the-columns-we-need-to-a-new-variable.-" data-toc-modified-id="-Assign-the-columns-we-need-to-a-new-variable.--3.1.8"><span class="toc-item-num">3.1.8&nbsp;&nbsp;</span> Assign the columns we need to a new variable. </a></span></li><li><span><a href="#-Rename-the-columns-appropriately-" data-toc-modified-id="-Rename-the-columns-appropriately--3.1.9"><span class="toc-item-num">3.1.9&nbsp;&nbsp;</span> Rename the columns appropriately </a></span></li><li><span><a href="#-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns).-" data-toc-modified-id="-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns).--3.1.10"><span class="toc-item-num">3.1.10&nbsp;&nbsp;</span> Know how many elements are within this variable (first number are rows and second number are columns). </a></span></li><li><span><a href="#-Sort-the-values-within-my-variable-in-descending-order.-" data-toc-modified-id="-Sort-the-values-within-my-variable-in-descending-order.--3.1.11"><span class="toc-item-num">3.1.11&nbsp;&nbsp;</span> Sort the values within my variable in descending order. </a></span></li></ul></li><li><span><a href="#Visualization-output" data-toc-modified-id="Visualization-output-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualization output</a></span><ul class="toc-item"><li><span><a href="#-Create-a-choropleth-map-of-the-data-set-within-my-selected-variable-and-label-it.-" data-toc-modified-id="-Create-a-choropleth-map-of-the-data-set-within-my-selected-variable-and-label-it.--3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span> Create a choropleth map of the data set within my selected variable and label it. </a></span></li></ul></li></ul></li><li><span><a href="#--Open-Street-Map-of-the-zip-code-with-high-and-low-median-household-incomes-in-LA-county.-" data-toc-modified-id="--Open-Street-Map-of-the-zip-code-with-high-and-low-median-household-incomes-in-LA-county.--4"><span class="toc-item-num">4&nbsp;&nbsp;</span>  Open Street Map of the zip code with high and low median household incomes in LA county. </a></span><ul class="toc-item"><li><span><a href="#Coding" data-toc-modified-id="Coding-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Coding</a></span><ul class="toc-item"><li><span><a href="#-Import-the-appropriate-libraries-and-extensions-to-read,-set-up-and-graph-the-data-appropriately." data-toc-modified-id="-Import-the-appropriate-libraries-and-extensions-to-read,-set-up-and-graph-the-data-appropriately.-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span> Import the appropriate libraries and extensions to read, set up and graph the data appropriately.</a></span></li><li><span><a href="#-Add-values-to-the-variables-that-I-will-use-for-the-Open-Street-Maps.-" data-toc-modified-id="-Add-values-to-the-variables-that-I-will-use-for-the-Open-Street-Maps.--4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span> Add values to the variables that I will use for the Open Street Maps. </a></span></li><li><span><a href="#-This-function-is-to-check-how-long-it-will-take-the-cell-to-run-the-function." data-toc-modified-id="-This-function-is-to-check-how-long-it-will-take-the-cell-to-run-the-function.-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span> This function is to check how long it will take the cell to run the function.</a></span></li><li><span><a href="#-Create-an-Open-Street-Map-using-the-variables-and-parameters-established-previously.-" data-toc-modified-id="-Create-an-Open-Street-Map-using-the-variables-and-parameters-established-previously.--4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span> Create an Open Street Map using the variables and parameters established previously. </a></span></li><li><span><a href="#-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns)." data-toc-modified-id="-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns).-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span> Know how many elements are within this variable (first number are rows and second number are columns).</a></span></li><li><span><a href="#-Know-what-kind-of-elements-are-within-this-variable." data-toc-modified-id="-Know-what-kind-of-elements-are-within-this-variable.-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span> Know what kind of elements are within this variable.</a></span></li><li><span><a href="#-Show-a-random-sample-of-10-data-entries-and-check-if-the-data-is-adequate." data-toc-modified-id="-Show-a-random-sample-of-10-data-entries-and-check-if-the-data-is-adequate.-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span> Show a random sample of 10 data entries and check if the data is adequate.</a></span></li><li><span><a href="#-List-all-the-column-names-that-are-included-within-the-data." data-toc-modified-id="-List-all-the-column-names-that-are-included-within-the-data.-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span> List all the column names that are included within the data.</a></span></li><li><span><a href="#-Get-information-as-to-what-kind-of-data-each-column-has-and-how-many-cells-have-values-in-them." data-toc-modified-id="-Get-information-as-to-what-kind-of-data-each-column-has-and-how-many-cells-have-values-in-them.-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span> Get information as to what kind of data each column has and how many cells have values in them.</a></span></li><li><span><a href="#-Assign-the-columns-I-want-to-keep-into-a-variable-and-see-a-sample-of-10-random-data-rows." data-toc-modified-id="-Assign-the-columns-I-want-to-keep-into-a-variable-and-see-a-sample-of-10-random-data-rows.-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span> Assign the columns I want to keep into a variable and see a sample of 10 random data rows.</a></span></li><li><span><a href="#-Get-information-as-to-what-kind-of-data-each-column-has-and-how-many-cells-have-values-in-them.-" data-toc-modified-id="-Get-information-as-to-what-kind-of-data-each-column-has-and-how-many-cells-have-values-in-them.--4.1.11"><span class="toc-item-num">4.1.11&nbsp;&nbsp;</span> Get information as to what kind of data each column has and how many cells have values in them. </a></span></li><li><span><a href="#-Count-how-many-elements-each-column-in-the-data-set-has.-" data-toc-modified-id="-Count-how-many-elements-each-column-in-the-data-set-has.--4.1.12"><span class="toc-item-num">4.1.12&nbsp;&nbsp;</span> Count how many elements each column in the data set has. </a></span></li><li><span><a href="#-Categorize-certain-columns-into-one-umbrella-category.-" data-toc-modified-id="-Categorize-certain-columns-into-one-umbrella-category.--4.1.13"><span class="toc-item-num">4.1.13&nbsp;&nbsp;</span> Categorize certain columns into one umbrella category. </a></span></li><li><span><a href="#-Count-how-many-elements-each-column-in-the-data-set-has.-" data-toc-modified-id="-Count-how-many-elements-each-column-in-the-data-set-has.--4.1.14"><span class="toc-item-num">4.1.14&nbsp;&nbsp;</span> Count how many elements each column in the data set has. </a></span></li></ul></li><li><span><a href="#Visualization-output" data-toc-modified-id="Visualization-output-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Visualization output</a></span><ul class="toc-item"><li><span><a href="#-Create-two-subplots-to-visualize-two-separate-data-sets.-" data-toc-modified-id="-Create-two-subplots-to-visualize-two-separate-data-sets.--4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span> Create two subplots to visualize two separate data sets. </a></span></li></ul></li></ul></li><li><span><a href="#-Time-Chart-of-the-Center-of-Medicaid-and-Medicare-Services-certification-for-each-clinic.-" data-toc-modified-id="-Time-Chart-of-the-Center-of-Medicaid-and-Medicare-Services-certification-for-each-clinic.--5"><span class="toc-item-num">5&nbsp;&nbsp;</span> Time Chart of the Center of Medicaid and Medicare Services certification for each clinic. </a></span><ul class="toc-item"><li><span><a href="#Coding" data-toc-modified-id="Coding-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Coding</a></span><ul class="toc-item"><li><span><a href="#-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.-" data-toc-modified-id="-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.--5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span> Read the file where the data is stored and assign it to a variable. </a></span></li><li><span><a href="#-Assign-a-column-of-the-data-set-to-a-variable-and-add-an-index.-" data-toc-modified-id="-Assign-a-column-of-the-data-set-to-a-variable-and-add-an-index.--5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span> Assign a column of the data set to a variable and add an index. </a></span></li><li><span><a href="#-Rename-the-columns-and-assign-it-to-a-variable.-" data-toc-modified-id="-Rename-the-columns-and-assign-it-to-a-variable.--5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span> Rename the columns and assign it to a variable. </a></span></li><li><span><a href="#-Sort-the-data-by-year.-" data-toc-modified-id="-Sort-the-data-by-year.--5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span> Sort the data by year. </a></span></li></ul></li><li><span><a href="#Visualization-output" data-toc-modified-id="Visualization-output-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Visualization output</a></span><ul class="toc-item"><li><span><a href="#-Create-a-time-chart-with-all-the-data.-" data-toc-modified-id="-Create-a-time-chart-with-all-the-data.--5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span> Create a time chart with all the data. </a></span></li></ul></li></ul></li><li><span><a href="#-Histogram-of-clinics-in-LA-county-by-license,-certification-or-both.-" data-toc-modified-id="-Histogram-of-clinics-in-LA-county-by-license,-certification-or-both.--6"><span class="toc-item-num">6&nbsp;&nbsp;</span> Histogram of clinics in LA county by license, certification or both. </a></span><ul class="toc-item"><li><span><a href="#Coding" data-toc-modified-id="Coding-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Coding</a></span><ul class="toc-item"><li><span><a href="#-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.-" data-toc-modified-id="-Read-the-file-where-the-data-is-stored-and-assign-it-to-a-variable.--6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span> Read the file where the data is stored and assign it to a variable. </a></span></li><li><span><a href="#-Visualize-the-first-five-rows-of-the-data.-" data-toc-modified-id="-Visualize-the-first-five-rows-of-the-data.--6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span> Visualize the first five rows of the data. </a></span></li><li><span><a href="#-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns).-" data-toc-modified-id="-Know-how-many-elements-are-within-this-variable-(first-number-are-rows-and-second-number-are-columns).--6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span> Know how many elements are within this variable (first number are rows and second number are columns). </a></span></li><li><span><a href="#-Assign-a-column-of-the-data-set-to-a-variable-and-add-an-index.-" data-toc-modified-id="-Assign-a-column-of-the-data-set-to-a-variable-and-add-an-index.--6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span> Assign a column of the data set to a variable and add an index. </a></span></li></ul></li><li><span><a href="#Visualization-output" data-toc-modified-id="Visualization-output-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Visualization output</a></span><ul class="toc-item"><li><span><a href="#-Create-a-bar-plot-with-the-data.-" data-toc-modified-id="-Create-a-bar-plot-with-the-data.--6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span> Create a bar plot with the data. </a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert-info"> <h1> Introduction </div>

# %% [markdown]
# <div class="alert-warning"> <h2> Research Question & Goals </div>

# %% [markdown]
# <center><b>How is the quality of service and the number of health establishments affected by the median household income of the zip code they are located in Los Angeles County? </center> </b>

# %% [markdown]
# * Our project is aimed to showcase the accessibility to health services depending on an income-based distribution within Los Angeles County.
#
# * By utilizing census and quantitative data we will be able to visualize how the distribution of health services is affected by the income of the population they are being offered to.
# * Our project will also provide insight as to how the Federal and State funds for health services are being allocated and if there are improvements needed to increase accessibility.

# %% [markdown]
# <div class="alert-warning"> <h2> Project Visualizations </div>

# %% [markdown]
# * Choropleth Map of Median Household Income by Zip Code in LA county.
# * Open Street Map of high and low median household income communities in LA County and the Services available.
# * Time Chart of the Center of Medicaid and Medicare Services certification for each clinic.
# * Histogram of clinics in LA county by license, certification, both or neither.

# %% [markdown]
# <div class="alert-info"> <h1> Choropleth Map of Median Household Income by Zip Code in LA county</div>

# %% [markdown]
# <div class="alert-warning"><h2>Coding</div>

# %% [markdown]
# <div class="alert-success"><h3> Import the appropriate libraries and extensions to read, set up and graph the data appropriately.

# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from geopandas import GeoDataFrame

# %% [markdown]
# Output: Libraries and extensions are ready for use.

# %% [markdown]
# <div class="alert-success"><h3> Read the file where the data is stored and assign it to a variable. </div>

# %%
income = gpd.read_file('income.geojson')

# %% [markdown]
# Output: the file has been read and is ready to be used for data analysis.

# %% [markdown]
# <div class="alert-success"><h3> Visualize all the rows and the columns in the data set without any limits/constraints. </div>

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Output: I can visualize all the columns in the dataset.

# %% [markdown]
# <div class="alert-success"><h3> Delete the row in the data that contains the LA County information to prevent errors in the output of data exploration. </div>

# %%
income = income.drop([0])

# %% [markdown]
# Output: The eliminated row will not affect the data set.

# %% [markdown]
# <div class="alert-success"><h3> Visualize the first five rows of the data to make sure there are no mistakes and the data set looks clean. </div>

# %%
income.head()
# Out:
#           geoid   name  B19013001  B19013001, Error  \
# 1  86000US90001  90001    43360.0            2437.0
# 2  86000US90002  90002    37285.0            1920.0
# 3  86000US90003  90003    40598.0            1743.0
# 4  86000US90004  90004    49675.0            1784.0
# 5  86000US90005  90005    38491.0            2241.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-118.26519 33.98923, -118.2620...
# 2  MULTIPOLYGON (((-118.26516 33.94643, -118.2651...
# 3  MULTIPOLYGON (((-118.28320 33.98914, -118.2826...
# 4  MULTIPOLYGON (((-118.33858 34.08346, -118.3381...
# 5  MULTIPOLYGON (((-118.29291 34.06360, -118.2923...

# %% [markdown]
# Output: The data is shown and I can make sure everything looks correct.

# %% [markdown]
# <div class="alert-success"><h3> Select the appropriate columns needed to make the data visualizations and assign them to a variable. </div>

# %%
columns_to_keep = ['geoid',
 'name','B19013001', 'geometry']

# %% [markdown]
# Output: Only these cells will be kept in the new variable.

# %% [markdown]
# <div class="alert-success"><h3> Visualize the first five rows of the data. </div>

# %%
income.head()
# Out:
#           geoid   name  B19013001  B19013001, Error  \
# 1  86000US90001  90001    43360.0            2437.0
# 2  86000US90002  90002    37285.0            1920.0
# 3  86000US90003  90003    40598.0            1743.0
# 4  86000US90004  90004    49675.0            1784.0
# 5  86000US90005  90005    38491.0            2241.0
#
#                                             geometry
# 1  MULTIPOLYGON (((-118.26519 33.98923, -118.2620...
# 2  MULTIPOLYGON (((-118.26516 33.94643, -118.2651...
# 3  MULTIPOLYGON (((-118.28320 33.98914, -118.2826...
# 4  MULTIPOLYGON (((-118.33858 34.08346, -118.3381...
# 5  MULTIPOLYGON (((-118.29291 34.06360, -118.2923...

# %% [markdown]
# Output: The data is shown and I can make sure everything looks correct.

# %% [markdown]
# <div class="alert-success"><h3> Assign the columns we need to a new variable. </div>

# %%
income = income[columns_to_keep]

# %% [markdown]
# Output: The kept columns are now in a new variable.

# %% [markdown]
# <div class="alert-success"><h3> Rename the columns appropriately </div>

# %%
income.columns = ['geoid',
 'name',
 'Median Household Income',
 'geometry']

# %% [markdown]
# Output: The columns have new names and can be called accordingly.

# %% [markdown]
# <div class="alert-success"><h3> Know how many elements are within this variable (first number are rows and second number are columns). </div>

# %%
income.shape
# Out:
# (302, 4)

# %% [markdown]
# Output: I know how much data I am working with and what kind of visualizations I can make.

# %% [markdown]
# <div class="alert-success"><h3> Sort the values within my variable in descending order. </div>

# %%
income_gdt = income.sort_values(by='Median Household Income', ascending = False)

# %% [markdown]
# Output: The cells are sorted from high to low values.

# %% [markdown]
# <div class="alert-warning"><h2>Visualization output</div>

# %% [markdown]
# <div class="alert-success"><h3> Create a choropleth map of the data set within my selected variable and label it. </div>

# %%
income_gdt.head(302).plot(figsize=(10,10),column='Median Household Income',legend=True, cmap='BuPu', label='Median Household income in US dollar')
plt.title('Median Household income distributed by zip code in LA county in 2019')
plt.figtext(0.588,0.09, "Map 1. This LA County choropleth map shows the Median Household Incomes in 2019 Inflation-adjusted dollars by zip code.", ha="center", fontsize=12, bbox={"facecolor":"white", "alpha":0, "pad":0})
plt.figtext(0.71,0.068, "The lowest median income per household is found in the Downtown LA area (90021) with a yearly median household income of $ 21,635. ", ha="center", fontsize=12, bbox={"facecolor":"white", "alpha":0, "pad":0})
plt.figtext(0.7259,0.047, "The highest median income per household is found in the Bel Air neighborhood (90077) with a yearly median household income of $ 209,531.", ha="center", fontsize=12, bbox={"facecolor":"white", "alpha":0, "pad":0})
# Out:
# Text(0.7259, 0.047, 'The highest median income per household is found in the Bel Air neighborhood (90077) with a yearly median household income of $ 209,531.')

# %% [markdown]
# <div class="alert-info"> <h1>  Open Street Map of the zip code with high and low median household incomes in LA county. </div>

# %% [markdown]
# <div class="alert-warning"><h2>Coding</div>

# %% [markdown]
# <div class="alert-success"><h3> Import the appropriate libraries and extensions to read, set up and graph the data appropriately.</div>

# %%
import osmnx as ox
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# Output: Libraries and extensions are ready for use.

# %% [markdown]
# <div class="alert-success"><h3> Add values to the variables that I will use for the Open Street Maps. </div>

# %%
address = '90048, CA'
tags = {'building':True}
dist = 1000 
address2 = '90021, CA'
tags2 = {'building':True}
dist2 = 1000

# %% [markdown]
# Output: The tags now have values to them and can be used by calling the function.

# %% [markdown]
# <div class="alert-success"><h3> This function is to check how long it will take the cell to run the function.</div>

# %%
# %%time
osm = ox.geometries_from_address(address,
                                 tags=tags,
                                 dist=dist)
# Out:
# CPU times: user 1.57 s, sys: 177 ms, total: 1.74 s
# Wall time: 9.74 s

# %%
# %%time
osm2 = ox.geometries_from_address(address2,
                                 tags=tags2,
                                 dist=dist2)
# Out:
# CPU times: user 525 ms, sys: 23 ms, total: 548 ms
# Wall time: 6.43 s

# %% [markdown]
# Output: I know how much time it will take the cell to run the function.

# %% [markdown]
# <div class="alert-success"><h3> Create an Open Street Map using the variables and parameters established previously. </div>

# %%
osm.plot(figsize=(10,10))
plt.title('90048, CA - Open Street Map')
# Out:
# Text(0.5, 1.0, '90048, CA - Open Street Map')

# %%
osm2.plot(figsize=(10,10))
plt.title('90021, CA - Open Street Map')
# Out:
# Text(0.5, 1.0, '90021, CA - Open Street Map')

# %% [markdown]
# Output: Create a simple Open Street Map.

# %% [markdown]
# <div class="alert-success"><h3> Know how many elements are within this variable (first number are rows and second number are columns).</div>

# %%
osm.shape
# Out:
# (6037, 60)

# %%
osm2.shape
# Out:
# (1537, 62)

# %% [markdown]
# Output: I know how much data I am working with and what kind of visualizations I can make.

# %% [markdown]
# <div class="alert-success"><h3> Know what kind of elements are within this variable.</div>

# %%
type(osm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
type(osm2)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Output: I can tell what commands I can use depending on the the kind of data I have.

# %% [markdown]
# <div class="alert-success"><h3> Show a random sample of 10 data entries and check if the data is adequate.</div>

# %%
osm.sample(10)
# Out:
#           unique_id      osmid element_type amenity  \
# 4471  way/428642094  428642094          way     NaN
# 4896  way/428647659  428647659          way     NaN
# 615   way/391066870  391066870          way     NaN
# 3964  way/428636106  428636106          way     NaN
# 450   way/391050530  391050530          way     NaN
# 3202  way/426398496  426398496          way     NaN
# 4374  way/428641972  428641972          way     NaN
# 4454  way/428642077  428642077          way     NaN
# 3621  way/428628273  428628273          way     NaN
# 5321  way/429345663  429345663          way     NaN
#
#                                                geometry addr:state  \
# 4471  POLYGON ((-118.36352 34.06979, -118.36352 34.0...        NaN
# 4896  POLYGON ((-118.36842 34.06851, -118.36828 34.0...        NaN
# 615   POLYGON ((-118.37182 34.07404, -118.37182 34.0...        NaN
# 3964  POLYGON ((-118.37234 34.06896, -118.37234 34.0...        NaN
# ...

# %% [markdown]
# Output: I can make sure that the data is correct and I can work with it.

# %% [markdown]
# <div class="alert-success"><h3> List all the column names that are included within the data.</div>

# %%
list(osm)
# Out:
# ['unique_id',
#  'osmid',
#  'element_type',
#  'amenity',
#  'geometry',
#  'addr:state',
#  'building',
#  'ele',
#  'gnis:county_name',
#  'gnis:feature_id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'name',
#  'source',
#  'nodes',
#  'building:levels',
#  'height',
#  'lacounty:ain',
#  'lacounty:bld_id',
#  'shop',
#  'start_date',
#  'wikidata',
#  'addr:city',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:street',
#  'operator',
#  'phone',
#  'website',
#  'emergency',
#  'parking',
#  'tourism',
#  'building:units',
#  'office',
#  'denomination',
#  'religion',
#  'access',
#  'opening_hours',
#  'roof:shape',
#  'building:use',
#  'name:zh',
#  'screen',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'dispensing',
#  'healthcare',
#  'short_name',
#  'fixme',
#  'historic',
#  'addr:country',
#  'email',
#  'wikipedia',
#  'cuisine',
#  'takeaway',
#  'club',
#  'sport',
#  'ways',
#  'type',
#  'old_name']

# %% [markdown]
# Output: I know what columns I have and which ones I can use.

# %% [markdown]
# <div class="alert-success"><h3> Get information as to what kind of data each column has and how many cells have values in them.</div>

# %%
osm.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 6037 entries, 0 to 6036
# Data columns (total 60 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   unique_id         6037 non-null   object
#  1   osmid             6037 non-null   int64
#  2   element_type      6037 non-null   object
#  3   amenity           16 non-null     object
#  4   geometry          6037 non-null   geometry
#  5   addr:state        14 non-null     object
#  6   building          6037 non-null   object
#  7   ele               5918 non-null   object
#  8   gnis:county_name  6 non-null      object
#  9   gnis:feature_id   8 non-null      object
#  10  gnis:import_uuid  6 non-null      object
#  11  gnis:reviewed     6 non-null      object
#  12  name              36 non-null     object
#  13  source            17 non-null     object
#  14  nodes             6034 non-null   object
#  15  building:levels   15 non-null     object
# ...

# %% [markdown]
# Output: Reads all the information of what kind of data my variables and columns have.

# %% [markdown]
# <div class="alert-success"><h3> Assign the columns I want to keep into a variable and see a sample of 10 random data rows.</div>

# %%
columns_to_keep = ['geometry','building','amenity']
osm = osm[columns_to_keep]
osm.sample(10)
# Out:
#                                                geometry     building amenity
# 1045  POLYGON ((-118.37012 34.07060, -118.37012 34.0...  residential     NaN
# 3280  POLYGON ((-118.36239 34.06228, -118.36234 34.0...        house     NaN
# 5389  POLYGON ((-118.36746 34.07490, -118.36746 34.0...        house     NaN
# 4158  POLYGON ((-118.37300 34.06829, -118.37301 34.0...        house     NaN
# 945   POLYGON ((-118.37364 34.07181, -118.37374 34.0...   apartments     NaN
# 3868  POLYGON ((-118.36666 34.06591, -118.36666 34.0...        house     NaN
# 4255  POLYGON ((-118.36709 34.07181, -118.36710 34.0...   apartments     NaN
# 5128  POLYGON ((-118.36704 34.06009, -118.36699 34.0...  residential     NaN
# 4321  POLYGON ((-118.36721 34.07087, -118.36722 34.0...   apartments     NaN
# 2978  POLYGON ((-118.36309 34.06488, -118.36310 34.0...  residential     NaN

# %% [markdown]
# Output: I only have specific columns in the variable I can work with now and I can ensure they look correct.

# %% [markdown]
# <div class="alert-success"><h3> Get information as to what kind of data each column has and how many cells have values in them. </div>

# %%
osm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 6037 entries, 0 to 6036
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  6037 non-null   geometry
#  1   building  6037 non-null   object
#  2   amenity   16 non-null     object
# dtypes: geometry(1), object(2)
# memory usage: 188.7+ KB

# %% [markdown]
# Output: Reads all the information of what kind of data my variables and columns have.

# %% [markdown]
# <div class="alert-success"><h3> Count how many elements each column in the data set has. </div>

# %%
osm.building.value_counts()
# Out:
# house          3424
# residential    1292
# apartments      625
# commercial      226
# retail          206
# yes             200
# hotel            20
# garage           13
# hospital         12
# garages           8
# industrial        5
# office            2
# roof              1
# parking           1
# warehouse         1
# school            1
# Name: building, dtype: int64

# %%
osm2.building.value_counts()
# Out:
# industrial      539
# warehouse       477
# yes             139
# retail          114
# commercial      101
# factory          47
# house            35
# apartments       31
# residential      29
# school           15
# parking           5
# hotel             2
# college           1
# roof              1
# kindergarten      1
# Name: building, dtype: int64

# %% [markdown]
# Output: I can see how much data each column has.

# %% [markdown]
# <div class="alert-success"><h3> Categorize certain columns into one umbrella category. </div>

# %%
osm.loc[osm['building']=='house','building'] = 'living facility'
osm.loc[osm['building']=='yes','building'] = 'living facility'
osm.loc[osm['building']=='hotel','building'] = 'living facility'
osm.loc[osm['building']=='residential','building'] = 'living facility'
osm.loc[osm['building']=='apartments','building'] = 'living facility'
osm.loc[osm['building']=='residential','building'] = 'living facility'
osm.loc[osm['building']=='garage','building'] = 'parking'
osm.loc[osm['building']=='garages','building'] = 'parking'
osm.loc[osm['building']=='parking','building'] = 'parking'
osm.loc[osm['building']=='parking','building'] = 'parking'
osm.loc[osm['building']=='industrial','building'] = 'work facility'
osm.loc[osm['building']=='retail','building'] = 'work facility'
osm.loc[osm['building']=='office','building'] = 'work facility'
osm.loc[osm['building']=='college','building'] = 'educational facility'
osm.loc[osm['building']=='warehouse','building'] = 'work facility'
osm.loc[osm['building']=='school','building'] = 'educational facility'

# %%
osm2.loc[osm2['building']=='house','building'] = 'living facility'
osm2.loc[osm2['building']=='yes','building'] = 'living facility'
osm2.loc[osm2['building']=='hotel','building'] = 'living facility'
osm2.loc[osm2['building']=='residential','building'] = 'living facility'
osm2.loc[osm2['building']=='apartments','building'] = 'living facility'
osm2.loc[osm2['building']=='residential','building'] = 'living facility'
osm2.loc[osm2['building']=='school','building'] = 'educational facility'
osm2.loc[osm2['building']=='kindergarten','building'] = 'educational facility'
osm2.loc[osm2['building']=='college','building'] = 'educational facility'
osm2.loc[osm2['building']=='warehouse','building'] = 'work facility'
osm2.loc[osm2['building']=='factory','building'] = 'work facility'
osm2.loc[osm2['building']=='retail','building'] = 'work facility'
osm2.loc[osm2['building']=='commercial','building'] = 'work facility'

# %% [markdown]
# Output: My visualization will look cleaner without as many categories.

# %% [markdown]
# <div class="alert-success"><h3> Count how many elements each column in the data set has. </div>

# %%
osm.building.value_counts()
# Out:
# living facility         5561
# commercial               226
# work facility            214
# parking                   22
# hospital                  12
# roof                       1
# educational facility       1
# Name: building, dtype: int64

# %%
osm2.building.value_counts()
# Out:
# work facility           739
# industrial              539
# living facility         236
# educational facility     17
# parking                   5
# roof                      1
# Name: building, dtype: int64

# %% [markdown]
# Output: I can get an idea as to what my visualization might look like.

# %% [markdown]
# <div class="alert-warning"><h2>Visualization output</div>

# %% [markdown]
# <div class="alert-success"><h3> Create two subplots to visualize two separate data sets. </div>

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 20))

osm.plot(ax =ax[0], figsize=(20,20), column='building',
         cmap='PRGn',
         legend=True)

ax[0].axis("off")
ax[0].set_title("Open Street Map - 90048 (Median Household Income: $100,586)")

osm2.plot(ax =ax[1], figsize=(20,20), column='building',
         cmap='BrBG',
         legend=True)
ax[1].axis("off")
ax[1].set_title("Open Street Map - 90021 (Median Household Income: $21,365)")
# Out:
# Text(0.5, 1.0, 'Open Street Map - 90021 (Median Household Income: $21,365)')

# %% [markdown]
# Map 2. In these Open Street Maps, the zip codes and buildings located within an area around these.

# %% [markdown]
# The left map is of the 90048 zip code area and has a total of 12 hospitals and a median household income of $100,586.

# %% [markdown]
# The right map is of the 90021 zip code area and has a total of 0 hospital and a median household income of $21,375.

# %% [markdown]
# <div class="alert-info"> <h1> Time Chart of the Center of Medicaid and Medicare Services certification for each clinic. </div>

# %% [markdown]
# <div class="alert-warning"><h2>Coding</div>

# %% [markdown]
# <div class="alert-success"><h3> Read the file where the data is stored and assign it to a variable. </div>

# %%
time_data = pd.read_csv('timedata1.csv')

# %% [markdown]
# Output: the file has been read and is ready to be used for data analysis.

# %% [markdown]
# <div class="alert-success"><h3> Assign a column of the data set to a variable and add an index. </div>

# %%
time_data = time_data['PARTICIPATION_DATE'].value_counts().reset_index()
time_data
# Out:
#      index  PARTICIPATION_DATE
# 0   2019.0                 262
# 1   2018.0                 195
# 2   2016.0                 159
# 3   2017.0                 152
# 4   2020.0                 146
# 5   2014.0                 139
# 6   2015.0                 132
# 7   2012.0                 112
# 8   2013.0                 107
# 9   2009.0                  98
# 10  2011.0                  97
# 11  2010.0                  96
# 12  2008.0                  90
# 13  2004.0                  81
# 14  2007.0                  79
# 15  2003.0                  71
# 16  1966.0                  70
# 17  2002.0                  57
# 18  1996.0                  55
# 19  1997.0                  52
# 20  1995.0                  50
# 21  1999.0                  48
# 22  1967.0                  47
# 23  2001.0                  46
# 24  1998.0                  44
# 25  2006.0                  42
# 26  1994.0                  40
# 27  2005.0                  37
# 28  1991.0                  34
# ...

# %% [markdown]
# Output: The data is organized and I can call it by the index.

# %% [markdown]
# <div class="alert-success"><h3> Rename the columns and assign it to a variable. </div>

# %%
time_data = time_data.rename(columns={'index':'year','PARTICIPATION_DATE':'count'})
time_data
# Out:
#       year  count
# 0   2019.0    262
# 1   2018.0    195
# 2   2016.0    159
# 3   2017.0    152
# 4   2020.0    146
# 5   2014.0    139
# 6   2015.0    132
# 7   2012.0    112
# 8   2013.0    107
# 9   2009.0     98
# 10  2011.0     97
# 11  2010.0     96
# 12  2008.0     90
# 13  2004.0     81
# 14  2007.0     79
# 15  2003.0     71
# 16  1966.0     70
# 17  2002.0     57
# 18  1996.0     55
# 19  1997.0     52
# 20  1995.0     50
# 21  1999.0     48
# 22  1967.0     47
# 23  2001.0     46
# 24  1998.0     44
# 25  2006.0     42
# 26  1994.0     40
# 27  2005.0     37
# 28  1991.0     34
# 29  1989.0     29
# 30  1993.0     26
# 31  1979.0     25
# 32  1976.0     24
# 33  1985.0     24
# 34  1971.0     23
# 35  1973.0     22
# 36  1990.0     22
# 37  1978.0     22
# 38  2000.0     22
# 39  1977.0     22
# 40  1987.0     20
# 41  1970.0     20
# 42  1992.0     20
# 43  1974.0     20
# 44  1972.0     18
# 45  1980.0     18
# 46  1986.0     18
# 47  1969.0     18
# 48  1968.0     17
# ...

# %% [markdown]
# Output: The data is now well defined.

# %% [markdown]
# <div class="alert-success"><h3> Sort the data by year. </div>

# %%
time_data = time_data.sort_values(by='year')

# %% [markdown]
# Output: The data is organized by date and now can be plotted.

# %% [markdown]
# <div class="alert-warning"><h2>Visualization output</div>

# %% [markdown]
# <div class="alert-success"><h3> Create a time chart with all the data. </div>

# %%
time_data.plot(figsize=(20,10), x='year', title='Count of the first year of Medicare and Medicaid Services in each healthcare facility of LA County', color='#148e99')
plt.legend().remove()
plt.grid(color='#b9c9c9', linestyle='-.', linewidth=0.75, axis='y', alpha=0.5)
plt.figtext(0.45,0.049, "Figure 2. This figure shows a timeline of the years in which each facility in LA County started participating in Center for Medicaid and Medicare Services.", ha="center", fontsize=12, bbox={"facecolor":"white", "alpha":0, "pad":0})
plt.figtext(0.167,0.029, " There is a very high spike in the participation count during the 2019 year with 262 facilities participating in CMS.", fontsize=12, bbox={"facecolor":"white", "alpha":0, "pad":0})
# Out:
# Text(0.167, 0.029, ' There is a very high spike in the participation count during the 2019 year with 262 facilities participating in CMS.')

# %% [markdown]
# <div class="alert-info"> <h1> Histogram of clinics in LA county by license, certification or both. </div>

# %% [markdown]
# <div class="alert-warning"><h2>Coding</div>

# %% [markdown]
# <div class="alert-success"><h3> Read the file where the data is stored and assign it to a variable. </div>

# %%
clinic = gpd.read_file('healthcare.csv')

# %% [markdown]
# Output: The file has been read and is ready to be used for data analysis.

# %% [markdown]
# <div class="alert-success"><h3> Visualize the first five rows of the data. </div>

# %%
clinic.head()
# Out:
#        LICENSED_CERTIFIED FLAG         T18_19      FACID FAC_STATUS_TYPE_CODE  \
# 0  LICENSED AND CERTIFIED       T18 OR T18/19  010000001                 OPEN
# 1  LICENSED AND CERTIFIED       T18 OR T18/19  010000003                 OPEN
# 2  LICENSED AND CERTIFIED       T18 OR T18/19  010000004                 OPEN
# 3  LICENSED AND CERTIFIED       T18 OR T18/19  010000005                 OPEN
# 4  LICENSED AND CERTIFIED       T18 OR T18/19  010000024                 OPEN
#
#    ASPEN_FACID     CCN TERMINAT_SW PARTICIPATION_DATE APPROVAL_DATE  \
# 0  CA010000001  555120                       7-Nov-80     14-Jan-20
# 1  CA010000003  056090                       1-Feb-74     13-Nov-19
# 2  CA010000004  056296                      14-Sep-71     26-Dec-19
# 3  CA010000005  555703                      18-Apr-97     13-Aug-19
# 4  CA010000024  056300                      10-Jul-73      6-May-19
#
#           NPI CAN_BE_DEEMED_FAC_TYPE CAN_BE_CERTIFIED_FAC_TYPE DEEMED  \
# ...

# %% [markdown]
# Output: The data is shown and I can make sure everything looks correct.

# %% [markdown]
# <div class="alert-success"><h3> Know how many elements are within this variable (first number are rows and second number are columns). </div>

# %%
c_count= clinic['LICENSED_CERTIFIED'].value_counts()
c_count
# Out:
# LICENSED AND CERTIFIED                 7919
# LICENSED ONLY                          2908
# CERTIFIED ONLY                         1131
# NOT LICENSED/NOT CERTIFIED              363
# EXEMPT FROM LICENSURE/NOT CERTIFIED       7
# Name: LICENSED_CERTIFIED, dtype: int64

# %% [markdown]
# Output: I can get an idea as to what my visualization might look like.

# %% [markdown]
# <div class="alert-success"><h3> Assign a column of the data set to a variable and add an index. </div>

# %%
c_count= c_count.reset_index()
c_count
# Out:
#                                  index  LICENSED_CERTIFIED
# 0               LICENSED AND CERTIFIED                7919
# 1                        LICENSED ONLY                2908
# 2                       CERTIFIED ONLY                1131
# 3           NOT LICENSED/NOT CERTIFIED                 363
# 4  EXEMPT FROM LICENSURE/NOT CERTIFIED                   7

# %% [markdown]
# Output: The data is more organized now and looks clean.

# %% [markdown]
# <div class="alert-warning"><h2>Visualization output</div>

# %% [markdown]
# <div class="alert-success"><h3> Create a bar plot with the data. </div>

# %%
c_count.plot.bar(x='index' , y='LICENSED_CERTIFIED', title="Number of Certified and Licensed Healthcare Facilities in LA County", color= ['#084e54', '#0f7b85', '#148e99', '#16aab8', '#16c8d9'])
plt.grid(color='#b9c9c9', linestyle='-.', linewidth=0.75, axis='y', alpha=0.3)
plt.xlabel('Type of Certification')
plt.ylabel('Count')
plt.legend().remove()
